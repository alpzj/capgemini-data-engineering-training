-- %% [markdown]
-- ### QUESTION 1: Employee Compensation Classification

-- %% [markdown]
-- ### Creating Table

-- %%
DROP TABLE IF EXISTS employee_payments;
CREATE TABLE employee_payments (

emp_id INT PRIMARY KEY,

emp_name VARCHAR(50),

department VARCHAR(30),

base_salary DECIMAL(10,2),

bonus DECIMAL(10,2),

joining_date DATE

);


INSERT INTO employee_payments VALUES

(1,'karthik','Data',75000.75,5000.50,'2019-03-15'),

(2,'veena','HR',65000.40,4000.25,'2021-06-20'),

(3,'ravi','Data',85000.90,6000.75,'2016-01-10'),

(4,'anil','Finance',70000.10,NULL,'2020-09-01'),

(5,'suresh','HR',60000.55,3000.30,'2022-11-25');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

-- %% [markdown]
-- ### · Convert emp_name to proper case ---upper /lower ---Initcap (CamelCase)

-- %%
SELECT emp_id,INITCAP(emp_name) AS emp_name
FROM employee_payments;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th></tr></thead><tbody><tr><td>1</td><td>Karthik</td></tr><tr><td>2</td><td>Veena</td></tr><tr><td>3</td><td>Ravi</td></tr><tr><td>4</td><td>Anil</td></tr><tr><td>5</td><td>Suresh</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Calculate Total Income (NULL-safe)

-- %%
SELECT emp_id,base_salary+COALESCE(bonus,0) AS total_income
FROM employee_payments;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>total_income</th></tr></thead><tbody><tr><td>1</td><td>80001.25</td></tr><tr><td>2</td><td>69000.65</td></tr><tr><td>3</td><td>91001.65</td></tr><tr><td>4</td><td>70000.10</td></tr><tr><td>5</td><td>63000.85</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Round Total Income

-- %%
SELECT emp_id,ROUND(base_salary+COALESCE(bonus,0)) AS total_income
FROM employee_payments;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>total_income</th></tr></thead><tbody><tr><td>1</td><td>80001</td></tr><tr><td>2</td><td>69001</td></tr><tr><td>3</td><td>91002</td></tr><tr><td>4</td><td>70000</td></tr><tr><td>5</td><td>63001</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Extract Joining Year

-- %%
SELECT emp_id,EXTRACT(YEAR FROM joining_date) AS joining_year
FROM employee_payments;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>joining_year</th></tr></thead><tbody><tr><td>1</td><td>2019</td></tr><tr><td>2</td><td>2021</td></tr><tr><td>3</td><td>2016</td></tr><tr><td>4</td><td>2020</td></tr><tr><td>5</td><td>2022</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Classify Employee Experience using CASE

-- %%
SELECT emp_id,
  CASE
    WHEN EXTRACT(YEAR FROM CURRENT_DATE)-EXTRACT(YEAR FROM joining_date)>7 THEN 'Senior'
    WHEN EXTRACT(YEAR FROM CURRENT_DATE)-EXTRACT(YEAR FROM joining_date) BETWEEN 4 AND 7 THEN 'Mid'
    ELSE 'Junior'
  END AS experience_level
FROM employee_payments;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>experience_level</th></tr></thead><tbody><tr><td>1</td><td>Mid</td></tr><tr><td>2</td><td>Mid</td></tr><tr><td>3</td><td>Senior</td></tr><tr><td>4</td><td>Mid</td></tr><tr><td>5</td><td>Mid</td></tr></tbody></table></div>

-- %% [markdown]
-- ### QUESTION 2: Order Delivery Delay Analysis

-- %% [markdown]
-- ### Creating Table

-- %%
CREATE TABLE orders_delivery (

order_id INT,

customer_name VARCHAR(50),

order_date DATE,

delivery_date DATE,

order_amount DECIMAL(10,2)

);


INSERT INTO orders_delivery VALUES

(101,'rajesh','2025-01-01','2025-01-05',12500.75),

(102,'meena','2025-01-10','2025-01-10',8400.40),

(103,'arun','2025-01-15','2025-01-20',15600.90),

(104,'pooja','2025-01-18',NULL,9200.10);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>4</td><td>4</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Uppercase Customer Name

-- %%
SELECT order_id,UPPER(customer_name) AS customer_name
FROM orders_delivery;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>customer_name</th></tr></thead><tbody><tr><td>101</td><td>RAJESH</td></tr><tr><td>102</td><td>MEENA</td></tr><tr><td>103</td><td>ARUN</td></tr><tr><td>104</td><td>POOJA</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Replace NULL Delivery Date with Today

-- %%
SELECT order_id,COALESCE(delivery_date,CURRENT_DATE) AS delivery_date
FROM orders_delivery;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>delivery_date</th></tr></thead><tbody><tr><td>101</td><td>2025-01-05</td></tr><tr><td>102</td><td>2025-01-10</td></tr><tr><td>103</td><td>2025-01-20</td></tr><tr><td>104</td><td>2026-04-09</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Calculate Delivery Days (date difference)

-- %%
SELECT order_id,COALESCE(delivery_date,CURRENT_DATE)-order_date AS delivery_days
FROM orders_delivery;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>delivery_days</th></tr></thead><tbody><tr><td>101</td><td>INTERVAL '4' DAY</td></tr><tr><td>102</td><td>INTERVAL '0' DAY</td></tr><tr><td>103</td><td>INTERVAL '5' DAY</td></tr><tr><td>104</td><td>INTERVAL '446' DAY</td></tr></tbody></table></div>

-- %% [markdown]
-- ### QUESTION 3: Customer Spending Pattern

-- %%
CREATE TABLE customer_spending (

cust_id INT,

cust_name VARCHAR(50),

city VARCHAR(30),

purchase_amount DECIMAL(10,2),

purchase_date DATE

);


INSERT INTO customer_spending VALUES

(1,'amit','mumbai',12000.75,'2024-12-01'),

(2,'neha','delhi',8500.40,'2024-12-15'),

(3,'rohit','mumbai',15500.90,'2024-11-20'),

(4,'kavya','chennai',6000.10,'2024-10-05');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>4</td><td>4</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Question
--
-- ##### Display:
--
-- ##### · Customer name with first letter capitalized
--
-- ##### · Month name of purchase
--
-- ##### · Rounded purchase amount
--
-- ##### · Absolute value of purchase (defensive logic)
--
-- ##### · CASE:
--
-- ##### o High spender > 15000
--
-- ##### o Medium 8000–15000
--
-- ##### o Low otherwise

-- %%
select concat(upper(substring(cust_name,1,1)),lower(substring(cust_name,2))) as cust_name
from customer_spending
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cust_name</th></tr></thead><tbody><tr><td>Amit</td></tr><tr><td>Neha</td></tr><tr><td>Rohit</td></tr><tr><td>Kavya</td></tr></tbody></table></div>

-- %%
select purchase_date,monthname(purchase_date) as month from customer_spending
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>purchase_date</th><th>month</th></tr></thead><tbody><tr><td>2024-12-01</td><td>Dec</td></tr><tr><td>2024-12-15</td><td>Dec</td></tr><tr><td>2024-11-20</td><td>Nov</td></tr><tr><td>2024-10-05</td><td>Oct</td></tr></tbody></table></div>

-- %%
select purchase_amount,round(purchase_amount,2) as pur_amount from customer_spending
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>purchase_amount</th><th>pur_amount</th></tr></thead><tbody><tr><td>12000.75</td><td>12000.75</td></tr><tr><td>8500.40</td><td>8500.40</td></tr><tr><td>15500.90</td><td>15500.90</td></tr><tr><td>6000.10</td><td>6000.10</td></tr></tbody></table></div>

-- %%
 select abs(purchase_amount) from customer_spending
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>abs(purchase_amount)</th></tr></thead><tbody><tr><td>12000.75</td></tr><tr><td>8500.40</td></tr><tr><td>15500.90</td></tr><tr><td>6000.10</td></tr></tbody></table></div>

-- %%
select *,
  CASE 
    WHEN purchase_amount > 15000 THEN 'HIGH SPENDER'
    WHEN purchase_amount between 8000 and 15000 THEN 'MEDIUM SPENDER'
    ELSE "LOW SPENDER"
  END AS Status
from customer_spending;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cust_id</th><th>cust_name</th><th>city</th><th>purchase_amount</th><th>purchase_date</th><th>Status</th></tr></thead><tbody><tr><td>1</td><td>amit</td><td>mumbai</td><td>12000.75</td><td>2024-12-01</td><td>MEDIUM SPENDER</td></tr><tr><td>2</td><td>neha</td><td>delhi</td><td>8500.40</td><td>2024-12-15</td><td>MEDIUM SPENDER</td></tr><tr><td>3</td><td>rohit</td><td>mumbai</td><td>15500.90</td><td>2024-11-20</td><td>HIGH SPENDER</td></tr><tr><td>4</td><td>kavya</td><td>chennai</td><td>6000.10</td><td>2024-10-05</td><td>LOW SPENDER</td></tr></tbody></table></div>

-- %% [markdown]
-- ### QUESTION 4: Subscription Validity Check

-- %%
CREATE TABLE subscriptions (

user_id INT,

user_email VARCHAR(100),

start_date DATE,

end_date DATE,

subscription_fee DECIMAL(10,2)

);


INSERT INTO subscriptions VALUES

(1,'karthik@gmail.com','2024-01-01','2025-01-01',12000.50),

(2,'veena@yahoo.com','2024-06-15','2024-12-15',8500.75),

(3,'ravi@hotmail.com','2023-03-01','2024-03-01',15000.90);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>3</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Question
--
-- ##### For each user:
--
-- ##### · Extract email domain
--
-- ##### · Calculate subscription duration in months
--
-- ##### · Format fee with commas
--
-- ##### · Find remaining days from today
--
-- ##### · CASE:
--
-- ##### o Active
--
-- ##### o Expiring Soon (≤30 days)
--
-- ##### o Expired

-- %%
select user_email,substring_index(user_email,'@',-1) as domain_mail from subscriptions
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_email</th><th>domain_mail</th></tr></thead><tbody><tr><td>karthik@gmail.com</td><td>gmail.com</td></tr><tr><td>veena@yahoo.com</td><td>yahoo.com</td></tr><tr><td>ravi@hotmail.com</td><td>hotmail.com</td></tr></tbody></table></div>

-- %%
select timestampdiff(month,start_date,end_date) as duration from subscriptions
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>duration</th></tr></thead><tbody><tr><td>12</td></tr><tr><td>6</td></tr><tr><td>12</td></tr></tbody></table></div>

-- %%
SELECT subscription_fee,format_number(subscription_fee, 2) AS formatted_fee
FROM subscriptions;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>subscription_fee</th><th>formatted_fee</th></tr></thead><tbody><tr><td>12000.50</td><td>12,000.50</td></tr><tr><td>8500.75</td><td>8,500.75</td></tr><tr><td>15000.90</td><td>15,000.90</td></tr></tbody></table></div>

-- %%
select datediff(end_date,curdate()) as remaining_days from subscriptions
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>remaining_days</th></tr></thead><tbody><tr><td>-464</td></tr><tr><td>-481</td></tr><tr><td>-770</td></tr></tbody></table></div>

-- %%
select *,
  case 
    when curdate() between start_date and end_date THEN 'Active'
    when datediff(end_date,curdate())<=30 and datediff(end_date,curdate())>0 then 'Expring soon'
    ELSE 'Expired'
  END AS subscription_status
from subscriptions
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_id</th><th>user_email</th><th>start_date</th><th>end_date</th><th>subscription_fee</th><th>subscription_status</th></tr></thead><tbody><tr><td>1</td><td>karthik@gmail.com</td><td>2024-01-01</td><td>2025-01-01</td><td>12000.50</td><td>Expired</td></tr><tr><td>2</td><td>veena@yahoo.com</td><td>2024-06-15</td><td>2024-12-15</td><td>8500.75</td><td>Expired</td></tr><tr><td>3</td><td>ravi@hotmail.com</td><td>2023-03-01</td><td>2024-03-01</td><td>15000.90</td><td>Expired</td></tr></tbody></table></div>

-- %% [markdown]
-- ### QUESTION 5: Loan EMI Risk Categorization

-- %%
CREATE TABLE loan_details (

loan_id INT,

customer_name VARCHAR(50),

loan_amount DECIMAL(12,2),

interest_rate DECIMAL(5,2),

loan_start DATE

);


INSERT INTO loan_details VALUES

(201,'suresh',500000.75,8.5,'2022-01-10'),

(202,'mahesh',750000.40,9.2,'2021-05-20'),

(203,'anita',300000.90,7.8,'2023-07-01');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>3</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Question
--
-- ##### Compute:
--
-- ##### · Monthly interest using power function
--
-- ##### · Years since loan start
--
-- ##### · Round EMI
--
-- ##### · Uppercase customer name
--
-- ##### · CASE:
--
-- ##### o High Risk if interest > 9
--
-- ##### o Medium Risk
--
-- ##### o Low Risk

-- %%
SELECT loan_id,UPPER(customer_name) AS customer_name_upper
FROM loan_details;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>loan_id</th><th>customer_name_upper</th></tr></thead><tbody><tr><td>201</td><td>SURESH</td></tr><tr><td>202</td><td>MAHESH</td></tr><tr><td>203</td><td>ANITA</td></tr></tbody></table></div>

-- %%
SELECT loan_id,interest_rate,
    CASE 
        WHEN interest_rate>9 THEN 'High Risk'
        WHEN interest_rate BETWEEN 8 AND 9 THEN 'Medium Risk'
        ELSE 'Low Risk'
    END AS risk_category
FROM loan_details;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>loan_id</th><th>interest_rate</th><th>risk_category</th></tr></thead><tbody><tr><td>201</td><td>8.50</td><td>Medium Risk</td></tr><tr><td>202</td><td>9.20</td><td>High Risk</td></tr><tr><td>203</td><td>7.80</td><td>Low Risk</td></tr></tbody></table></div>

-- %% [markdown]
-- ### QUESTION 6: Employee Attendance Evaluation

-- %%
CREATE TABLE attendance (

emp_id INT,

emp_name VARCHAR(50),

total_days INT,

present_days INT,

record_date DATE

);


INSERT INTO attendance VALUES

(1,'karthik',30,28,'2025-01-31'),

(2,'veena',30,22,'2025-01-31'),

(3,'ravi',30,18,'2025-01-31');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>3</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Question
--
-- ##### Calculate:
--
-- ##### · Attendance percentage (rounded)
--
-- ##### · Month name
--
-- ##### · Difference between total and present days
--
-- ##### · Lowercase employee name
--
-- ##### · CASE:
--
-- ##### o Excellent ≥90%
--
-- ##### o Average 75–89%
--
-- ##### o Poor otherwise

-- %%
SELECT emp_id,LOWER(emp_name) AS emp_name_lower,ROUND((present_days * 100.0) / total_days) AS attendance_percentage,MONTHNAME(record_date) AS month_name,(total_days - present_days) AS absent_days,
    CASE 
        WHEN (present_days * 100.0) / total_days >= 90 THEN 'Excellent'
        WHEN (present_days * 100.0) / total_days BETWEEN 75 AND 89 THEN 'Average'
        ELSE 'Poor'
    END AS performance
FROM attendance;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name_lower</th><th>attendance_percentage</th><th>month_name</th><th>absent_days</th><th>performance</th></tr></thead><tbody><tr><td>1</td><td>karthik</td><td>93</td><td>Jan</td><td>2</td><td>Excellent</td></tr><tr><td>2</td><td>veena</td><td>73</td><td>Jan</td><td>8</td><td>Poor</td></tr><tr><td>3</td><td>ravi</td><td>60</td><td>Jan</td><td>12</td><td>Poor</td></tr></tbody></table></div>

-- %% [markdown]
-- ### QUESTION 7: Product Discount Validation

-- %%
CREATE TABLE product_sales (

product_id INT,

product_name VARCHAR(50),

mrp DECIMAL(10,2),

selling_price DECIMAL(10,2),

sale_date DATE

);

INSERT INTO product_sales VALUES

(1,'Laptop',75000.75,68000.50,'2025-01-10'),

(2,'Mobile',35000.40,33000.25,'2025-01-12'),

(3,'Tablet',25000.90,26000.75,'2025-01-15');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>3</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Question
--
-- ##### Derive:
--
-- ##### · Discount amount (absolute)
--
-- ##### · Discount percentage
--
-- ##### · Day name of sale
--
-- ##### · Proper case product name
--
-- ##### · CASE:
--
-- ##### o Valid Discount
--
-- ##### o Overpriced
--
-- ##### o No Discount

-- %%
SELECT product_id,INITCAP(product_name) AS product_name,mrp,selling_price,
    ROUND(mrp - selling_price, 2) AS discount_amount,
    ROUND(((mrp - selling_price) / mrp) * 100, 2) AS discount_percentage,
    TO_CHAR(sale_date, 'Day') AS sale_day,
    CASE 
        WHEN selling_price < mrp THEN 'Valid Discount'
        WHEN selling_price > mrp THEN 'Overpriced'
        ELSE 'No Discount'
    END AS discount_status
FROM product_sales;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>product_name</th><th>mrp</th><th>selling_price</th><th>discount_amount</th><th>discount_percentage</th><th>sale_day</th><th>discount_status</th></tr></thead><tbody><tr><td>1</td><td>Laptop</td><td>75000.75</td><td>68000.50</td><td>7000.25</td><td>9.33</td><td>10AM2025</td><td>Valid Discount</td></tr><tr><td>2</td><td>Mobile</td><td>35000.40</td><td>33000.25</td><td>2000.15</td><td>5.71</td><td>12AM2025</td><td>Valid Discount</td></tr><tr><td>3</td><td>Tablet</td><td>25000.90</td><td>26000.75</td><td>-999.85</td><td>-4.00</td><td>15AM2025</td><td>Overpriced</td></tr></tbody></table></div>

-- %% [markdown]
-- ### QUESTION 8: Insurance Policy Aging

-- %%
DROP TABLE IF EXISTS insurance_policies;
CREATE TABLE insurance_policies (

policy_id INT,

holder_name VARCHAR(50),

premium_amount DECIMAL(10,2),

policy_start DATE,

policy_end DATE

);

INSERT INTO insurance_policies VALUES

(301,'arjun',12000.50,'2023-01-01','2026-01-01'),

(302,'megha',8500.75,'2022-06-15','2025-06-15'),

(303,'vinod',15000.90,'2021-03-01','2024-03-01');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>3</td></tr></tbody></table></div>

-- %% [markdown]
-- ##### Question
--
-- ##### Show:
--
-- ##### · Policy duration in years
--
-- ##### · Remaining days
--
-- ##### · Rounded premium
--
-- ##### · Uppercase holder name
--
-- ##### · CASE:
--
-- ##### o Long Term
--
-- ##### o Mid Term
--
-- ##### o Expired

-- %%
SELECT policy_id,UPPER(holder_name) AS holder_name,premium_amount,ROUND(premium_amount) AS rounded_premium,policy_start,policy_end,
    ROUND(DATEDIFF(policy_end, policy_start) / 365.0, 2) AS policy_duration_years,
    DATEDIFF(policy_end, CURRENT_DATE) AS remaining_days,
    CASE 
        WHEN policy_end < CURRENT_DATE THEN 'Expired'
        WHEN DATEDIFF(policy_end, policy_start) / 365.0 >= 3 THEN 'Long Term'
        ELSE 'Mid Term'
    END AS policy_status
FROM insurance_policies;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>policy_id</th><th>holder_name</th><th>premium_amount</th><th>rounded_premium</th><th>policy_start</th><th>policy_end</th><th>policy_duration_years</th><th>remaining_days</th><th>policy_status</th></tr></thead><tbody><tr><td>301</td><td>ARJUN</td><td>12000.50</td><td>12001</td><td>2023-01-01</td><td>2026-01-01</td><td>3.00</td><td>-101</td><td>Expired</td></tr><tr><td>302</td><td>MEGHA</td><td>8500.75</td><td>8501</td><td>2022-06-15</td><td>2025-06-15</td><td>3.00</td><td>-301</td><td>Expired</td></tr><tr><td>303</td><td>VINOD</td><td>15000.90</td><td>15001</td><td>2021-03-01</td><td>2024-03-01</td><td>3.00</td><td>-772</td><td>Expired</td></tr></tbody></table></div>

-- %% [markdown]
-- ### QUESTION 9: Salary Increment Simulation

-- %%
CREATE TABLE salary_revision (

emp_id INT,

emp_name VARCHAR(50),

current_salary DECIMAL(10,2),

rating INT,

last_hike DATE

);

INSERT INTO salary_revision VALUES

(1,'karthik',75000.75,5,'2023-01-01'),

(2,'veena',65000.40,4,'2024-01-01'),

(3,'ravi',85000.90,3,'2022-01-01');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>3</td></tr></tbody></table></div>

-- %% [markdown]
-- ##### Question
--
-- ##### Calculate:
--
-- ##### · Years since last hike
--
-- ##### · Increment using rating logic
--
-- ##### · New salary (rounded)
--
-- ##### · Lowercase name
--
-- ##### · CASE:
--
-- ##### o High Increment
--
-- ##### o Moderate
--
-- ##### o No Increment

-- %%
SELECT emp_id,LOWER(emp_name) AS emp_name,current_salary,rating,
    ROUND(DATEDIFF(CURRENT_DATE, last_hike) / 365.0, 2) AS years_since_last_hike,
    CASE 
        WHEN rating = 5 THEN current_salary * 0.20
        WHEN rating = 4 THEN current_salary * 0.15
        WHEN rating = 3 THEN current_salary * 0.10
        ELSE 0
    END AS increment_amount,
    ROUND(
        current_salary + 
        CASE 
            WHEN rating = 5 THEN current_salary * 0.20
            WHEN rating = 4 THEN current_salary * 0.15
            WHEN rating = 3 THEN current_salary * 0.10
            ELSE 0
        END
    ) AS new_salary,
    CASE 
        WHEN rating = 5 THEN 'High Increment'
        WHEN rating IN (3, 4) THEN 'Moderate'
        ELSE 'No Increment'
    END AS increment_status
FROM salary_revision;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>current_salary</th><th>rating</th><th>years_since_last_hike</th><th>increment_amount</th><th>new_salary</th><th>increment_status</th></tr></thead><tbody><tr><td>1</td><td>karthik</td><td>75000.75</td><td>5</td><td>3.28</td><td>15000.1500</td><td>90001</td><td>High Increment</td></tr><tr><td>2</td><td>veena</td><td>65000.40</td><td>4</td><td>2.28</td><td>9750.0600</td><td>74750</td><td>Moderate</td></tr><tr><td>3</td><td>ravi</td><td>85000.90</td><td>3</td><td>4.28</td><td>8500.0900</td><td>93501</td><td>Moderate</td></tr></tbody></table></div>

-- %% [markdown]
-- ### QUESTION 10: Customer Account Status Evaluation

-- %%
CREATE TABLE bank_accounts (

account_id INT,

customer_name VARCHAR(50),

balance DECIMAL(12,2),

last_transaction DATE,

branch VARCHAR(30)

);


INSERT INTO bank_accounts VALUES

(501,'ramesh',125000.75,'2024-12-20','hyderabad'),

(502,'sita',8500.40,'2023-06-15','delhi'),

(503,'manoj',-2500.90,'2025-01-05','mumbai');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>3</td></tr></tbody></table></div>

-- %% [markdown]
-- ##### Question
--
-- ##### Determine:
--
-- ##### · Absolute balance
--
-- ##### · Days since last transaction
--
-- ##### · Proper case branch name
--
-- ##### · Sign of balance
--
-- #####· CASE:
--
-- ##### o Active
--
-- ##### o Dormant
--
-- ##### o Overdrawn

-- %%
SELECT account_id,customer_name,balance,ABS(balance) AS absolute_balance,
    DATEDIFF(CURRENT_DATE, last_transaction) AS days_since_last_transaction,
    INITCAP(branch) AS branch,
    CASE 
        WHEN balance > 0 THEN 'Positive'
        WHEN balance < 0 THEN 'Negative'
        ELSE 'Zero'
    END AS balance_sign,
    CASE 
        WHEN balance < 0 THEN 'Overdrawn'
        WHEN DATEDIFF(CURRENT_DATE, last_transaction) > 365 THEN 'Dormant'
        ELSE 'Active'
    END AS account_status
FROM bank_accounts;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>account_id</th><th>customer_name</th><th>balance</th><th>absolute_balance</th><th>days_since_last_transaction</th><th>branch</th><th>balance_sign</th><th>account_status</th></tr></thead><tbody><tr><td>501</td><td>ramesh</td><td>125000.75</td><td>125000.75</td><td>478</td><td>Hyderabad</td><td>Positive</td><td>Dormant</td></tr><tr><td>502</td><td>sita</td><td>8500.40</td><td>8500.40</td><td>1032</td><td>Delhi</td><td>Positive</td><td>Dormant</td></tr><tr><td>503</td><td>manoj</td><td>-2500.90</td><td>2500.90</td><td>462</td><td>Mumbai</td><td>Negative</td><td>Overdrawn</td></tr></tbody></table></div>
