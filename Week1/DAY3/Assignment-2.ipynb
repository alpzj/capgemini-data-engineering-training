-- %% [markdown]
-- ### CREATING TABLE

-- %%
DROP tABLE IF EXISTS CustomerUsage;
CREATE TABLE CustomerUsage (
customer_id INT PRIMARY KEY,
customer_name VARCHAR(50),
plan_type VARCHAR(20),
data_used_gb INT,
call_minutes INT,
monthly_bill DECIMAL(10,2)
);

INSERT INTO CustomerUsage VALUES
(1, 'Veena', 'Postpaid', 9, 471, 842.03),
(2, 'Veer', 'Postpaid', 7, 354, 434.94),
(3, 'Mohan', 'Prepaid', 33, 497, 569.23),
(4, 'Pratik', 'Prepaid', 15, 113, 1107.48),
(5, 'Farhan', 'Prepaid', 14, 1284, 845.75),
(6, 'Jiya', 'Postpaid', 28, 1578, 1325.15);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>6</td><td>6</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Plan Upgrade Suggestion

-- %%
%sql
SELECT customer_name,
CASE 
    WHEN plan_type = 'Prepaid' AND (monthly_bill > 400 OR call_minutes > 550)
        THEN 'Suggest Postpaid Upgrade'
    WHEN plan_type = 'Prepaid'
        THEN 'No Upgrade'
    WHEN plan_type = 'Postpaid' AND data_used_gb > 25
        THEN 'Suggest Premium Plan'
    ELSE 'Satisfactory Usage'
END AS upgrade_suggestion
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_name</th><th>upgrade_suggestion</th></tr></thead><tbody><tr><td>Veena</td><td>Satisfactory Usage</td></tr><tr><td>Veer</td><td>Satisfactory Usage</td></tr><tr><td>Mohan</td><td>Suggest Postpaid Upgrade</td></tr><tr><td>Pratik</td><td>Suggest Postpaid Upgrade</td></tr><tr><td>Farhan</td><td>Suggest Postpaid Upgrade</td></tr><tr><td>Jiya</td><td>Suggest Premium Plan</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Customer Classification

-- %%
SELECT customer_name,
CASE 
    WHEN plan_type = 'Postpaid' AND data_used_gb >= 30
        THEN 'Heavy User - Postpaid'
    WHEN plan_type = 'Postpaid' AND data_used_gb BETWEEN 15 AND 29
        THEN 'Moderate User - Postpaid'
    WHEN plan_type = 'Postpaid'
        THEN 'Light User - Postpaid'
    WHEN plan_type = 'Prepaid' AND data_used_gb >= 20
        THEN 'Heavy User - Prepaid'
    ELSE 'Light User - Prepaid'
END AS user_classification
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_name</th><th>user_classification</th></tr></thead><tbody><tr><td>Veena</td><td>Light User - Postpaid</td></tr><tr><td>Veer</td><td>Light User - Postpaid</td></tr><tr><td>Mohan</td><td>Heavy User - Prepaid</td></tr><tr><td>Pratik</td><td>Light User - Prepaid</td></tr><tr><td>Farhan</td><td>Light User - Prepaid</td></tr><tr><td>Jiya</td><td>Moderate User - Postpaid</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Voice Usage Pattern

-- %%
SELECT customer_name,
CASE 
    WHEN call_minutes > 1200 AND monthly_bill > 1000
        THEN 'Excessive Talker - Premium'
    WHEN call_minutes > 1200
        THEN 'Excessive Talker - Standard'
    WHEN call_minutes BETWEEN 800 AND 1200
        THEN 'Frequent Caller'
    ELSE 'Normal Caller'
END AS voice_pattern
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_name</th><th>voice_pattern</th></tr></thead><tbody><tr><td>Veena</td><td>Normal Caller</td></tr><tr><td>Veer</td><td>Normal Caller</td></tr><tr><td>Mohan</td><td>Normal Caller</td></tr><tr><td>Pratik</td><td>Normal Caller</td></tr><tr><td>Farhan</td><td>Excessive Talker - Standard</td></tr><tr><td>Jiya</td><td>Excessive Talker - Premium</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Offer Eligibility

-- %%
SELECT customer_name,
CASE 
    WHEN plan_type = 'Postpaid' AND data_used_gb > 25 AND call_minutes > 1000
        THEN 'Combo Offer'
    WHEN plan_type = 'Prepaid' AND monthly_bill > 600
        THEN 'Recharge Cashback Offer'
    ELSE 'No Offer'
END AS offer_eligibility
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_name</th><th>offer_eligibility</th></tr></thead><tbody><tr><td>Veena</td><td>No Offer</td></tr><tr><td>Veer</td><td>No Offer</td></tr><tr><td>Mohan</td><td>No Offer</td></tr><tr><td>Pratik</td><td>Recharge Cashback Offer</td></tr><tr><td>Farhan</td><td>Recharge Cashback Offer</td></tr><tr><td>Jiya</td><td>Combo Offer</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Reward Program

-- %%
SELECT customer_name,
CASE 
    WHEN data_used_gb > 25 AND call_minutes > 1000
        THEN 'Gold Tier'
    WHEN data_used_gb > 25
        THEN 'Silver Tier'
    WHEN call_minutes > 800
        THEN 'Bronze Tier'
    ELSE 'Basic Tier'
END AS reward_tier
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_name</th><th>reward_tier</th></tr></thead><tbody><tr><td>Veena</td><td>Basic Tier</td></tr><tr><td>Veer</td><td>Basic Tier</td></tr><tr><td>Mohan</td><td>Silver Tier</td></tr><tr><td>Pratik</td><td>Basic Tier</td></tr><tr><td>Farhan</td><td>Bronze Tier</td></tr><tr><td>Jiya</td><td>Gold Tier</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Mismatch Detection

-- %%
SELECT customer_name,
CASE 
    WHEN plan_type = 'Postpaid' AND monthly_bill < 500
        THEN 'Underutilized Postpaid'
    WHEN plan_type = 'Prepaid' AND monthly_bill > 900
        THEN 'Overpaying Prepaid'
    ELSE 'Plan Matches Usage'
END AS usage_match
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_name</th><th>usage_match</th></tr></thead><tbody><tr><td>Veena</td><td>Plan Matches Usage</td></tr><tr><td>Veer</td><td>Underutilized Postpaid</td></tr><tr><td>Mohan</td><td>Plan Matches Usage</td></tr><tr><td>Pratik</td><td>Overpaying Prepaid</td></tr><tr><td>Farhan</td><td>Plan Matches Usage</td></tr><tr><td>Jiya</td><td>Plan Matches Usage</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Heavy All-Round Users

-- %%
SELECT customer_name,
CASE 
    WHEN data_used_gb > 25 AND call_minutes > 1000 AND monthly_bill > 1200
        THEN 'Super User'
    WHEN data_used_gb > 25 AND call_minutes > 1000
        THEN 'High Usage Customer'
    ELSE 'Standard User'
END AS user_type
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_name</th><th>user_type</th></tr></thead><tbody><tr><td>Veena</td><td>Standard User</td></tr><tr><td>Veer</td><td>Standard User</td></tr><tr><td>Mohan</td><td>Standard User</td></tr><tr><td>Pratik</td><td>Standard User</td></tr><tr><td>Farhan</td><td>Standard User</td></tr><tr><td>Jiya</td><td>Super User</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Voice vs Data Preference

-- %%
SELECT customer_name,
CASE 
    WHEN call_minutes > data_used_gb * 30
        THEN 'Voice Oriented User'
    WHEN data_used_gb > call_minutes / 30
        THEN 'Data Oriented User'
    ELSE 'Balanced Usage'
END AS usage_preference
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_name</th><th>usage_preference</th></tr></thead><tbody><tr><td>Veena</td><td>Voice Oriented User</td></tr><tr><td>Veer</td><td>Voice Oriented User</td></tr><tr><td>Mohan</td><td>Data Oriented User</td></tr><tr><td>Pratik</td><td>Data Oriented User</td></tr><tr><td>Farhan</td><td>Voice Oriented User</td></tr><tr><td>Jiya</td><td>Voice Oriented User</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Billing Discount Suggestion

-- %%
SELECT customer_name,
CASE 
    WHEN monthly_bill > 1000 AND plan_type = 'Prepaid'
        THEN 'Offer Switch + Discount'
    WHEN monthly_bill > 1000 AND plan_type = 'Postpaid'
        THEN 'Offer Loyalty Discount'
    ELSE 'No Discount'
END AS discount_offer
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_name</th><th>discount_offer</th></tr></thead><tbody><tr><td>Veena</td><td>No Discount</td></tr><tr><td>Veer</td><td>No Discount</td></tr><tr><td>Mohan</td><td>No Discount</td></tr><tr><td>Pratik</td><td>Offer Switch + Discount</td></tr><tr><td>Farhan</td><td>No Discount</td></tr><tr><td>Jiya</td><td>Offer Loyalty Discount</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Digital Engagement Tag

-- %%
SELECT customer_name,
CASE 
    WHEN data_used_gb > 25 AND monthly_bill < 700
        THEN 'High Efficiency User'
    WHEN data_used_gb > 25
        THEN 'Premium Digital User'
    ELSE 'Standard Engagement'
END AS engagement_tag
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_name</th><th>engagement_tag</th></tr></thead><tbody><tr><td>Veena</td><td>Standard Engagement</td></tr><tr><td>Veer</td><td>Standard Engagement</td></tr><tr><td>Mohan</td><td>High Efficiency User</td></tr><tr><td>Pratik</td><td>Standard Engagement</td></tr><tr><td>Farhan</td><td>Standard Engagement</td></tr><tr><td>Jiya</td><td>Premium Digital User</td></tr></tbody></table></div>

-- %% [markdown]
-- ###Usage Behavior

-- %%
SELECT customer_name,
CASE 
    WHEN call_minutes > 1500 AND data_used_gb < 10
        THEN 'Heavy Voice, Low Data'
    WHEN data_used_gb > 25 AND call_minutes < 500
        THEN 'Heavy Data, Light Talk'
    ELSE 'Balanced or Low Usage'
END AS usage_behavior
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_name</th><th>usage_behavior</th></tr></thead><tbody><tr><td>Veena</td><td>Balanced or Low Usage</td></tr><tr><td>Veer</td><td>Balanced or Low Usage</td></tr><tr><td>Mohan</td><td>Heavy Data, Light Talk</td></tr><tr><td>Pratik</td><td>Balanced or Low Usage</td></tr><tr><td>Farhan</td><td>Balanced or Low Usage</td></tr><tr><td>Jiya</td><td>Balanced or Low Usage</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Customer Type

-- %%
SELECT customer_name,
CASE 
    WHEN plan_type = 'Postpaid' AND monthly_bill > 800 AND call_minutes > 1200
        THEN 'Elite Postpaid User'
    WHEN plan_type = 'Postpaid' AND monthly_bill > 800
        THEN 'Premium Postpaid User'
    WHEN plan_type = 'Prepaid'
        THEN 'Prepaid User'
END AS customer_type
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_name</th><th>customer_type</th></tr></thead><tbody><tr><td>Veena</td><td>Premium Postpaid User</td></tr><tr><td>Veer</td><td>null</td></tr><tr><td>Mohan</td><td>Prepaid User</td></tr><tr><td>Pratik</td><td>Prepaid User</td></tr><tr><td>Farhan</td><td>Prepaid User</td></tr><tr><td>Jiya</td><td>Elite Postpaid User</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Data Pack Suggestion

-- %%
SELECT customer_name,
CASE 
    WHEN data_used_gb > 20 AND monthly_bill BETWEEN 800 AND 1000
        THEN 'Gold Data Pack Suggested'
    WHEN data_used_gb > 30
        THEN 'Platinum Data Pack Suggested'
    ELSE 'Standard Plan'
END AS data_pack
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_name</th><th>data_pack</th></tr></thead><tbody><tr><td>Veena</td><td>Standard Plan</td></tr><tr><td>Veer</td><td>Standard Plan</td></tr><tr><td>Mohan</td><td>Platinum Data Pack Suggested</td></tr><tr><td>Pratik</td><td>Standard Plan</td></tr><tr><td>Farhan</td><td>Standard Plan</td></tr><tr><td>Jiya</td><td>Standard Plan</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Talker Category

-- %%
SELECT customer_name,
CASE 
    WHEN call_minutes > 1000 AND monthly_bill < 700
        THEN 'Value Talker'
    WHEN call_minutes > 1000
        THEN 'Premium Talker'
    ELSE 'Normal Caller'
END AS talker_type
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_name</th><th>talker_type</th></tr></thead><tbody><tr><td>Veena</td><td>Normal Caller</td></tr><tr><td>Veer</td><td>Normal Caller</td></tr><tr><td>Mohan</td><td>Normal Caller</td></tr><tr><td>Pratik</td><td>Normal Caller</td></tr><tr><td>Farhan</td><td>Premium Talker</td></tr><tr><td>Jiya</td><td>Premium Talker</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Power User Identification

-- %%
SELECT customer_name,
CASE 
    WHEN plan_type = 'Prepaid' AND data_used_gb > 25
        THEN 'Prepaid Power User'
    WHEN plan_type = 'Postpaid' AND data_used_gb > 25
        THEN 'Postpaid Power User'
    ELSE 'Normal User'
END AS power_user_status
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_name</th><th>power_user_status</th></tr></thead><tbody><tr><td>Veena</td><td>Normal User</td></tr><tr><td>Veer</td><td>Normal User</td></tr><tr><td>Mohan</td><td>Prepaid Power User</td></tr><tr><td>Pratik</td><td>Normal User</td></tr><tr><td>Farhan</td><td>Normal User</td></tr><tr><td>Jiya</td><td>Postpaid Power User</td></tr></tbody></table></div>
